# %% [markdown]
# Regroupement of all kinds of plots for the WSM-metal system:
# * $A(\omega,k_x)$ -- already a lot of these done
# * $A(k_x,k_z)$ -- already a lot of these done
# * $A(\omega,k_z)$
# * vary $\mu$ on surface
# * split by spins $\sigma_x$, $\sigma_z$
# * $<\sigma_i>$
# * with and without tunnelling
# * at each boundary

# %%
import weyl_plots as wp
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/Users/leogoutte/Desktop/Masters Research/Code and notebooks/weylsemimetal_tools")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Looking along the $k_x$ axis

# %% [markdown]
# At the weyl point

# %%
As_0 = wp.SpectralFunctionArray(size=60,res=100,plot_type="xw",xrange=1.5,yrange=1.5,w=0,kx=0,kz=-np.pi/2,t=1,g=0,mu=-4,r=2.3,surface=True,side=1,spin=+1,spin_dir="x")

# %%
res=100
plt.imshow(As_0,cmap='inferno')
plt.ylim(0,res)
plt.yticks([0,int(res/2),res],labels=["$-2$","0","$2$"])
plt.xticks([0,int(res/2)-1/2,res-1],labels=["$-2$","0","$2$"])
plt.xlabel(r"$k_x$")
plt.ylabel(r"$\omega$")
plt.colorbar()
plt.show()

# %%
res=100
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0,surface=False,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0.8,surface=False,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=1,surface=False,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=1.5,surface=False,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=2.3,surface=False,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_0,As_08,As_1,As_15,As_23)

# %% [markdown]
# Outside the topological region ($|k_z|>\pi /2$)

# %%
res=100
kz = np.pi
# note: spectrum is symmetric wrt kz
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=0,surface=False,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=0.8,surface=False,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=1,surface=False,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=1.5,surface=False,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=np.pi,yrange=2,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=2.3,surface=False,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_0,As_08,As_1,As_15,As_23)

# %% [markdown]
# Inside the topological region ($|k_z|<\pi /2$)

# %%
res=100
kz = 0.
# note: spectrum is symmetric wrt kz
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=2,yrange=0.8,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=0,surface=False,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=2,yrange=0.8,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=0.8,surface=False,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=2,yrange=0.8,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=1,surface=False,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=2,yrange=0.8,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=1.5,surface=False,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=2,yrange=0.8,w=0,kx=0,kz=kz,t=1,g=0,mu=-4,r=2.3,surface=False,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_0,As_08,As_1,As_15,As_23)

# %% [markdown]
# Looking along the $k_z$ axis -- the Fermi arc

# %%
res=100
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0,surface=False,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0.8,surface=False,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=1,surface=False,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=1.5,surface=False,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=2.3,surface=False,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_0,As_08,As_1,As_15,As_23)

# %% [markdown]
# As a function of $k_x$ for a fixed tunnelling $r=2.3$

# %%
res=100
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=-0.5,kz=np.pi/2,t=1,g=0,mu=-4,r=0.5,surface=False,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=-0.25,kz=np.pi/2,t=1,g=0,mu=-4,r=0.5,surface=False,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0.5,surface=False,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0.25,kz=np.pi/2,t=1,g=0,mu=-4,r=0.5,surface=False,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=20,res=100,plot_type="zw",xrange=np.pi,yrange=0.9,w=0,kx=0.5,kz=np.pi/2,t=1,g=0,mu=-4,r=0.5,surface=False,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_0,As_08,As_1,As_15,As_23,kname="k_z")

# %% [markdown]
# Vary $\mu$ and look at surface spectral function at interface. Does the right band lie on the chemical potential (i.e. does it come from the metal?)

# %%
res=100
r=2.3
kz=np.pi/2
wrange=4
As_a = wp.SpectralFunctionArray(size=20,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=-0.5,kz=kz,t=1,g=0,mu=-0,r=r,surface=True,side=1,spin=0,spin_dir="z")
As_b = wp.SpectralFunctionArray(size=20,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=-0.25,kz=kz,t=1,g=0,mu=-1,r=r,surface=True,side=1,spin=0,spin_dir="z")
As_c = wp.SpectralFunctionArray(size=20,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0,kz=kz,t=1,g=0,mu=-2,r=r,surface=True,side=1,spin=0,spin_dir="z")
As_d = wp.SpectralFunctionArray(size=20,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0.25,kz=kz,t=1,g=0,mu=-3,r=r,surface=True,side=1,spin=0,spin_dir="z")
As_e = wp.SpectralFunctionArray(size=20,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0.5,kz=kz,t=1,g=0,mu=-4,r=r,surface=True,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_a,As_b,As_c,As_d,As_e,kname="k_x")

# %%
res=100
r=2.3
kz=np.pi/2
wrange=4
As_a = np.zeros((res,res),dtype=float)
As_b = np.zeros((res,res),dtype=float)
As_c = np.zeros((res,res),dtype=float)
As_d = np.zeros((res,res),dtype=float)
As_e = np.zeros((res,res),dtype=float)

for i in range(res):
    kx = np.linspace(-np.pi,np.pi,res)[i]
    As_a[:,i] = wp.FullSpectralFunctionWeylWK(size=50,res=res,kx=kx,kz=kz,t=1,g=0,mu=0,r=2.3)
    As_b[:,i] = wp.FullSpectralFunctionWeylWK(size=50,res=res,kx=kx,kz=kz,t=1,g=0,mu=-1,r=2.3)
    As_c[:,i] = wp.FullSpectralFunctionWeylWK(size=50,res=res,kx=kx,kz=kz,t=1,g=0,mu=-2,r=2.3)
    As_d[:,i] = wp.FullSpectralFunctionWeylWK(size=50,res=res,kx=kx,kz=kz,t=1,g=0,mu=-3,r=2.3)
    As_e[:,i] = wp.FullSpectralFunctionWeylWK(size=50,res=res,kx=kx,kz=kz,t=1,g=0,mu=-4,r=2.3)

# %%
wp.FivePlots(As_a,As_b,As_c,As_d,As_e,kname="k_x")

# %%
def Convert(value,res,maxrange):
    """
    Converts value to resolution
    Assume minrange = -maxrange
    """
    m = res / (2 * maxrange)
    b = m * maxrange
    y = m * value + b
    return y

# %%
res=100
plt.imshow(As_e,cmap='inferno')
plt.ylim(0,res)
plt.yticks([0,int(res/2),res],labels=["$-4$","0","$4$"])
plt.xticks([0,int(res/2)-1/2,res-1],labels=["$-\pi$","0","$\pi$"])
plt.xlabel(r"$k_x$")
plt.ylabel(r"$\omega$")
plt.axhline(Convert(0,res,wrange))
plt.colorbar()
plt.show()

# %% [markdown]
# Vary tunnelling at Weyl node

# %%
res=100
mu=-2
kz=np.pi/2
wrange=4
As_0 = wp.SpectralFunctionArray(size=50,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=-0.5,kz=kz,t=1,g=0,mu=mu,r=0,surface=True,side=1,spin=0,spin_dir="z")
As_08 = wp.SpectralFunctionArray(size=50,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=-0.25,kz=kz,t=1,g=0,mu=mu,r=0.8,surface=True,side=1,spin=0,spin_dir="z")
As_1 = wp.SpectralFunctionArray(size=50,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0,kz=kz,t=1,g=0,mu=mu,r=1,surface=True,side=1,spin=0,spin_dir="z")
As_15 = wp.SpectralFunctionArray(size=50,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0.25,kz=kz,t=1,g=0,mu=mu,r=1.5,surface=True,side=1,spin=0,spin_dir="z")
As_23 = wp.SpectralFunctionArray(size=50,res=res,plot_type="xw",xrange=np.pi,yrange=wrange,w=0,kx=0.5,kz=kz,t=1,g=0,mu=mu,r=2.3,surface=True,side=1,spin=0,spin_dir="z")

# %%
wp.FivePlots(As_a,As_b,As_c,As_d,As_e,kname="k_x")

# %% [markdown]
# Looking at the spin of the fledgling boundary state
#
# This is a mirroring/continuation of the work in `WeylSpins.ipynb`

# %% [markdown]
# Understanding the $r\rightarrow \infty $ limit

# %%
res=100
As_0 = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=1,yrange=1,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=0,surface=True,side=1,spin=0,spin_dir="z")
As_between = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=1,yrange=1,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=2,surface=True,side=1,spin=0,spin_dir="z")
As_infty = wp.SpectralFunctionArray(size=20,res=100,plot_type="xw",xrange=1,yrange=1,w=0,kx=0,kz=np.pi/2,t=1,g=0,mu=-4,r=100,surface=True,side=1,spin=0,spin_dir="z")

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,sharey=True,figsize=(10,5))

im0 = ax[0].imshow(As_0,cmap='inferno')
ax[0].set_ylim(0,res)
ax[0].set_yticks([0,int(res/2),res])
ax[0].set_yticklabels(["$-1t$","0","$1t$"])
ax[0].set_xticks([0,int(res/2)-1/2,res-1])
ax[0].set_xticklabels([r"-$1$",r"0",r"$1$"])
ax[0].set_xlabel(r"$k_x$")
ax[0].set_ylabel(r"$\omega$")

divider = make_axes_locatable(ax[0])
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im0, cax=cax, orientation='vertical')

im1 = ax[1].imshow(As_between,cmap='inferno')
ax[1].set_xlabel(r"$k_x$")
ax[1].set_xticks([0,int(res/2)-1/2,res-1])
ax[1].set_xticklabels([r"-$1$",r"0",r"$1$"])

divider = make_axes_locatable(ax[1])
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im1, cax=cax, orientation='vertical')

im2 = ax[2].imshow(As_infty,cmap='inferno')
ax[2].set_xlabel(r"$k_x$")
ax[2].set_xticks([0,int(res/2)-1/2,res-1])
ax[2].set_xticklabels([r"-$1$",r"0",r"$1$"])

divider = make_axes_locatable(ax[2])
cax = divider.append_axes('right', size='5%', pad=0.05)
fig.colorbar(im2, cax=cax, orientation='vertical')

plt.show()

# %%
size=100
ks,es,vs=wp.Spectrum(size=size,kz=0,t=1,g=0,mu=-4,r=50000,bulk=0)

fig1, ax1 = plt.subplots()
fig1.subplots_adjust(left=0.16, bottom=0.2, right=0.99, top=0.97)
plt.plot(ks,es)
plt.xlabel(r"$k_x$")
plt.ylabel(r"$E$")
ax1 = fig1.add_axes([0.68, 0.64, 0.3, 0.3]) 
ax1.plot(ks,es)
ax1.set_ylim(-6,6)
ax1.set_xlim(-2,2)

plt.show()

# %%
plt.plot(np.arange(2*size),np.abs(vs[:,0,50]))
plt.xlabel(r"$y$")
plt.ylabel(r"$|\psi|$")
plt.show()
